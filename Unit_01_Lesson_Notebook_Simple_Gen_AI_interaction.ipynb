# %% [markdown]
# # lesson_1_Simple_Gen_AI_Examples
#
# **Purpose:**
#
# In the Friday lecture we described a number of attributes we expect an intelligent person to have.  We want our Gen AI models to display many attributes:
#
#   * **Knowledgeable** - we want to see evidence of *breadth* of knowledge.  As a generalist, the model should be well-informed about a very wide variety of topics
#   * **Erudite** - we also want to see evidence of *depth* of knowledge equivalent to advanced academic study of a subject
#   * **Eloquent** - we want the model to be able to express ideas well to a variety of different audiences
#   * **Rational** - we want the model to be able to reason. Given a problem or puzzle, we want the model to solve it correctly.
#   * **Novel** - we want the model to emit unique content and not to simply copy and paste together old content
#   * **Obedient** - we want the model to accurately interpret and follow our instructions as in "do what I mean."
#
# We will try to ask some questions/give some instructions that require a model to display those attributes.  You should also run this notebook and test the model(s) yourself.

# %% [markdown]
# **Description:**
#
# There are a variety of ways of accessing Gen AI models.  In this notebook we will show you two smaller and free ones.<br>
#
# Section 1 is about accessing ChatGPT via a web interface.  This allows you to experiment and to copy and paste but it does not allow you to access the model programatically.  We'll talk about that later.
#
# Section 2 is about using the HuggingFace Transformer libraries and models in the repository.  Here we are using a new model just deployed by Microsoft that is very performant despite it's small size.  This model is part of a current trend to improve efficiency and to squeeze more and more performance out of smaller and smaller models.  This Microsoft model will fit onto one GPU.  Other models may require multiple GPUs to load and run.
#
# Section 3 demonstrates calling OpenAI's top model.  You'll need your own paid API key to run that code.
#
# Section 4 runs the latest models from Microsoft Phi-4-mini and Alibaba's Qwen3.  We'll make extensive use of Hugging Face models in this class because we can run it in free Colab.
#
# <a id = 'returnToTop'></a>
#
# ## Notebook Contents
#   * 1. Commercial Models
#     * 1.1 [Open AI ChatGPT](#chatgpt)
#     * 1.2 [Anthopic Claude](#claude)
#     * 1.3 [Google Gemini](#gemini)
#   * 2. [Hugging Face and Phi-4-mini](#huggingface)
#   * 3. [Open AI API Access](#openai)
#   * 4. [Qwen 3](#qwen3)
#
#
# **To run this notebook** you should copy it to your personal Colab Plus Google account by uploading it into your Google Drive. From there you can open it as a Colab notebook and run it.  It needs a GPU to run and it needs enough memory to load these 3.84 billion parameter models.

# %% [markdown]
# [Return to Top](#returnToTop)
# <a id = 'chatgpt'></a>
# ## 1.1 ChatGPT
#
# You can access a [free version of ChatGPT here](https://chatgpt.com/).  You will need to create an account (unless you already have one) using your personal and **NOT your @berkeley.edu account**.  This model can only be accessed via a web browser.  Later we will create pay as you go accounts that will allow you call these models from a notebook using your unique key.  We'll do it in a way that minimizes your expenses.
#
# Let's access ChatGPT and try a couple of super simple prompts to see how well it performs.  It can be a very handy tool.

# %% [markdown]
# ### 1.1.1 Prompts
#
# As noted above there are a number of attributes we want to see demonstrated from the models if we are to think of them as intelligent.  Here are seven prompts that capture some of those attributes.  Think about which attributes they capture and how well they capture them.  You'll be able to run this notebook and test your own prompts.
#
# Prompt 1 - ```Please write a five sentence explanation of how LLMs do knowledge representation.```
#
# Prompt 2 - ```Complete the following limerick that begins: There once was a man from Gibraltar ```
#
# Prompt 3 - ```You are a world renowned baker with many awards and Michelin stars.  Give us your world famous recipe for chocolate chip cookies.```
#
# Prompt 4 - ```Complete the following haiku about LLMs that begins: Modeling language ```
#
# Prompt 5 - ```Write a function in python to take an input string, break it down into words and return all of the word level tri-grams it contains.```
#
# Prompt 6 - ```Miriam has seven books and two podcasts.  Marwan has five papers and a regular lecture series.  Who has published more?```
#
# Prompt 7 - ```List the countries in Europe along with their capital cities.
# ```
#
# How did those perform with ChatGPT?  These prompts are very simplistic.  Later in the semester we'll talk about a variety of ways of improving the output.  We'll also look at much more complex prompts.

# %% [markdown]
# [Return to Top](#returnToTop)
# <a id = 'claude'></a>
# ## 1.2 Anthropic Claude
#
# You can access a [free version of Claude here](https://claude.ai/).  You will need to create an account (unless you already have one) using your personal and **NOT your @berkeley.edu account**.  You want to use Claude 3.7 Sonnet if possible.  This model can only be accessed via a web browser.  Later we will create pay as you go accounts that will allow you call these models from a notebook using your unique key.  We'll do it in a way that minimizes your expenses.
#
# Let's access Claude and try a couple of super simple prompts to see how well it performs.  It can be a very handy tool.

# %% [markdown]
# [Return to Top](#returnToTop)
# <a id = 'gemini'></a>
# ## 1.3 Google Gemini
#
# You can access a [free version of Gemini here](https://gemini.google.com/).  You will need to create an account (unless you already have one) using your personal and **NOT your @berkeley.edu account**.  You want to use Gemini 2.0 Flash.  This model can only be accessed via a web browser.  Later we will create pay as you go accounts that will allow you call these models from a notebook using your unique key.  We'll do it in a way that minimizes your expenses.
#
# Let's access Gemini and try a couple of super simple prompts to see how well it performs.  It can be a very handy tool.

# %% [markdown]
# [Return to Top](#returnToTop)
# <a id = 'huggingface'></a>
# ## 2. Hugging Face
#
# Hugging Face is a company that offers a library of "transformers" as well as pre-trained models geared for a variety of tasks.  We are going to explore several ways of working with these models at a very high level.  In later classes, when we have covered how a transformer works, we'll come back and look at them at a deeper level.  This tutorial is designed to look at the HuggingFace library at the highest most abstract level -- the pipeline.
#
# Note that HuggingFace supports PyTorch and an alternative called Tensorflow.  The default language for HuggingFace is PyTorch.  They port many of their models to Tensorflow.  When using Huggingface just pay attention to which version you're using.  When the model you're using is TensorFlow, the model name often begins with TF as in TFBert or TFDistilBert.  If it doesn't have a TF at the begining of the model name, it is using PyTorch which is the language we'll be using in this class.
#
#
# The [HuggingFace web site](https://huggingface.co/transformers) offers an interesting set of resources.  Their [model documentation](https://huggingface.co/transformers/model_summary.html) provides an excellent explanation of transformers as well as the growing variety of models they offer (see the left hand navigation column).  In addition, their collection of [notebooks](https://huggingface.co/transformers/notebooks.html) is a valuable set of examples.  Their [blog](https://huggingface.co/blog) has some interesting and useful posts about how transformers of all varieties work. Their LLM leader board keeps track of the [performance of open source models.](https://huggingface.co/open-llm-leaderboard)  Finally, they offer [an excellent set of tutorials](https://huggingface.co/docs/transformers/index) as well as a Quick Start Guide with videos on the use of the full Hugging Face family of resources.
#
# ---
#
# One word of caution:  this is a rapidly evolving resource and as a result you can often run in to bugs.  They will get fixed, eventually, but may be buggy for a while.

# %%
# !pip install -q -U transformers  #>=4.51.0
# !pip install einops
# !pip install -q -U accelerate  #>=1.5.0
# !pip install -q -U bitsandbytes
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (0.8.1)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 10.3 MB/s eta 0:00:00

# %% [markdown]
# We'll use a brand new model from Microsoft called PHI-4-mini.  It stands out because it is relatively small at 3.8 billion paramters but has a 128K context window.  Let's look at [the model card](https://huggingface.co/microsoft/Phi-4-mini-instruct) from Hugging Face to get more background on just what distinguishes it from others.  Note it is optimized for common sense, language understanding, math, code, long context and logical reasoning.

# %%
#In case we want to know our installed transformers library version
# !pip list | grep transformers
# !pip list | grep accelerate
# Out:
# sentence-transformers                 3.4.1
# transformers                          4.51.3
# accelerate                            1.6.0

# %% [markdown]
# Add the following to make sure we are using the GPU if it will fit in the GPU's memory.

# %%
import torch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# This will allow us to print output with a large horizontal scroll bar.

# %%
from pprint import pprint

# %% [markdown]
# Now, let's load some Hugging Face abstractions -- AutoModelForCausalLM, AutoTokenizer, and the pipeline.  These make it very easy to just try a model and see how it performs.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

torch.random.manual_seed(0)

# %% [markdown]
# ## Instantiate Model

# %% [markdown]
# Now let's load the actual Microsoft model.  We'll be using Phi-4-mini-instruct.  This is a model designed to give quick answers.  Sometimes, depending on your problem, such a short thought model is what's best for you.  Other times, like if doing math, logic, or puzzles then a longer thought reasoning model is most approrpaite.  After you've run all seven prompts with the short thought model you can uncomment the reasoning model line and comment the instruct line and then try the reasonong model to see how it performs.

# %%
phi_model = AutoModelForCausalLM.from_pretrained(
    #"microsoft/Phi-4-mini-reasoning",
    "microsoft/Phi-4-mini-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
    attn_implementation="eager"
)
#phi_tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-4-mini-reasoning")
phi_tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-4-mini-instruct")
# Out:
# config.json:   0%|          | 0.00/2.50k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/10.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-4-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/54.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-4-mini-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/16.3k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.77G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.93k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.91M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]

# %% [markdown]
# What is the meaning of the string - `microsoft/Phi-4-mini-instruct`.  The `microsoft` portion means it comes from Microsoft. `Phi-4` is the name of the model.  `Mini` refers to the variant of the model usually indicating the number of parameters. Finally, `instruct` means this model has been instruction fine tuned and shuold be good at following our instructions.
#
# Now we can run the model.  We'll construct our prompt which we'll put in the messages list.  Note that the model is trained to do some dialog.  We can toggle back and forth between the 'user' and 'assistant' roles.  We can also just feed in the initial 'user' field if we just want one prompt.
#
# Since this model is pre-trained for math and logical reasoning, let's try it with a simple equation.

# %%
#This shows the turn-taking conversational approach. The first user and assistant pair represents the first turn in the conversation.
#We'll typically just use one 'user' input.
messages = [
    {"role": "user", "content": "Can you provide ways to eat combinations of bananas and dragonfruits?"},
    {"role": "assistant", "content": "Sure! Here are some ways to eat bananas and dragonfruits together: 1. Banana and dragonfruit smoothie: Blend bananas and dragonfruits together with some milk and honey. 2. Banana and dragonfruit salad: Mix sliced bananas and dragonfruits together with some lemon juice and honey."},
    {"role": "user", "content": "What about solving an 2x + 3 = 7 equation?"},
]

phi_pipe = pipeline(
    "text-generation",
    model=phi_model,
    tokenizer=phi_tokenizer,
)

generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.1,
    "do_sample": True,
}

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'],compact=True)
# Out:
# Device set to use cuda
# ('To solve the equation 2x + 3 = 7, follow these steps:\n'
#  '\n'
#  '1. Subtract 3 from both sides of the equation to isolate the term with the '
#  'variable (x) on one side:\n'
#  '   2x + 3 - 3 = 7 - 3\n'
#  '   2x = 4\n'
#  '\n'
#  '2. Divide both sides of the equation by 2 to solve for x:\n'
#  '   2x / 2 = 4 / 2\n'
#  '   x = 2\n'
#  '\n'
#  'So, the solution to the equation 2x + 3 = 7 is x = 2.')

# %% [markdown]
# Before we try the prompts we specified in the intro, let's start with a completion task example.  We'll give the begining of the sentence and let it predict what comes next.

# %%
phi_pipe = pipeline("text-generation",
                model=phi_model,
                tokenizer=phi_tokenizer,
                trust_remote_code=True)

output = phi_pipe("Today is such a wonderful", do_sample=True, top_p=0.95, temperature=0.7, max_new_tokens=50)
#print(output

#print(output)
pprint(output[0]['generated_text'], compact=True)
# Out:
# Device set to use cuda
# ('Today is such a wonderful day and the weather is gorgeous. We have just '
#  'moved into our new home and we are still getting used to it. I hope the '
#  'weather stays nice all week. I have been planning a picnic for this Saturday '
#  'and I want to take my friends with')

# %% [markdown]
# Let's do that again but without any args, just the prompt and the defaults of the system.  It tends to produce more verbose output when we just rely on the defaults.

# %%
messages = [
    {"role": "user", "content": "Today is such a wonderful"},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ("I'm glad to hear that you're having a wonderful day! If there's anything "
#  "specific you'd like to talk about or do, feel free to let me know. I'm here "
#  'to help!')

# %% [markdown]
# Let's ask the model how it thinks that LLMs model represent knowledge.

# %%
#prompt 1
messages = [
    {"role": "user", "content": "Please write a five sentence explanation of how LLMs do knowledge representation."},
]

generation_args['max_new_tokens'] = 1500
output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ('Large Language Models (LLMs) represent knowledge through a combination of '
#  'vast amounts of data, sophisticated algorithms, and neural network '
#  'architectures. They ingest and process diverse text sources, enabling them '
#  'to understand and generate human-like text. Through techniques like '
#  'attention mechanisms and transformer architectures, LLMs can capture '
#  'relationships between words and concepts, facilitating nuanced understanding '
#  'and context-aware responses. By leveraging pre-training on extensive '
#  'corpora, LLMs develop a broad knowledge base that encompasses various '
#  'domains and topics. Fine-tuning further refines their capabilities, allowing '
#  'them to apply this knowledge effectively in specific tasks and applications.')

# %% [markdown]
# We want our model to be a generalist.  Let's try a completely unrelated task, specifically let's have the model write some poetry, starting with a limerick.  This is challenging because it requires rhyming.

# %%
#prompt 2
pmessages = [
    {"role": "user", "content": "Complete the following limerick that begins There once was a man from Gibraltar "},
]

output = phi_pipe(pmessages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ('There once was a man from Gibraltar,\n'
#  'Whose love for the sea was quite fair.\n'
#  'He sailed on the waves,\n'
#  'With a hearty, brave laugh,\n'
#  'And found treasures beyond compare.')

# %% [markdown]
# Now let's see if the model can give us a good recipe for chocolate chip cookies.  We care about the ingredients and we care about the instructions.  Let's try and encourage a good recipe with our prompt.

# %%
#prompt 3
messages = [
    {"role": "user", "content": "You are a world renowned baker with many awards and Michelin stars.  Give us your world famous recipe for chocolate chip cookies."},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ("Thank you for your kind words! I'm thrilled to share my world-famous "
#  'chocolate chip cookie recipe with you. This recipe has been perfected over '
#  'years of baking and has earned numerous accolades, including Michelin stars. '
#  'Here it is:\n'
#  '\n'
#  '**World-Famous Chocolate Chip Cookies Recipe**\n'
#  '\n'
#  '**Ingredients:**\n'
#  '\n'
#  '- 1 cup (2 sticks) unsalted butter, softened\n'
#  '- 1 cup granulated sugar\n'
#  '- 1 cup packed brown sugar\n'
#  '- 2 large eggs\n'
#  '- 2 teaspoons vanilla extract\n'
#  '- 3 cups all-purpose flour\n'
#  '- 1 teaspoon baking soda\n'
#  '- 1/2 teaspoon baking powder\n'
#  '- 1/2 teaspoon salt\n'
#  '- 2 cups semisweet chocolate chips\n'
#  '- 1 cup chopped walnuts (optional)\n'
#  '\n'
#  '**Instructions:**\n'
#  '\n'
#  '1. **Preheat the Oven:**\n'
#  '   Preheat your oven to 350°F (175°C). Line baking sheets with parchment '
#  'paper or silicone baking mats.\n'
#  '\n'
#  '2. **Cream the Butter and Sugars:**\n'
#  '   In a large mixing bowl, cream together the softened butter, granulated '
#  'sugar, and brown sugar until light and fluffy. This should take about 2-3 '
#  'minutes with an electric mixer on medium speed.\n'
#  '\n'
#  '3. **Add the Eggs and Vanilla:**\n'
#  '   Beat in the eggs one at a time, ensuring each egg is fully incorporated '
#  'before adding the next. Add the vanilla extract and mix well.\n'
#  '\n'
#  '4. **Combine Dry Ingredients:**\n'
#  '   In a separate bowl, whisk together the flour, baking soda, baking powder, '
#  'and salt. Gradually add the dry ingredients to the wet mixture, mixing until '
#  'just combined. Be careful not to overmix.\n'
#  '\n'
#  '5. **Fold in the Chocolate Chips and Walnuts:**\n'
#  '   Gently fold in the chocolate chips and chopped walnuts (if using) until '
#  'evenly distributed throughout the dough.\n'
#  '\n'
#  '6. **Scoop and Bake:**\n'
#  '   Using a cookie scoop or tablespoon, drop rounded balls of dough onto the '
#  'prepared baking sheets, spacing them about 2 inches apart. Flatten each ball '
#  'slightly with the back of the scoop or your hand.\n'
#  '\n'
#  '7. **Bake:**\n'
#  '   Bake in the preheated oven for 10-12 minutes, or until the edges are '
#  'golden brown but the centers are still soft. The cookies will continue to '
#  'cook slightly on the baking sheets after being removed from the oven.\n'
#  '\n'
#  '8. **Cool:**\n'
#  '   Allow the cookies to cool on the baking sheets for 5 minutes before '
#  'transferring them to wire racks to cool completely.\n'
#  '\n'
#  '**Notes:**\n'
#  '\n'
#  '- For an extra touch of decadence, you can add a pinch of sea salt to the '
#  'dough before baking.\n'
#  '- If you prefer a chewier cookie, you can slightly underbake them and let '
#  'them finish cooking on the baking sheets.\n'
#  '- Feel free to experiment with different types of chocolate chips or add-ins '
#  'like dried fruit, coconut, or even a sprinkle of sea salt.\n'
#  '\n'
#  'Enjoy your delicious, award-winning chocolate chip cookies with a glass of '
#  'milk or your favorite hot beverage. Bon appétit!')

# %% [markdown]
# Do you think the generated recipe contains a good set of ingredients? Would you want to eat the cookie as desribed. Let's try a more complex task for the model.  Can it produce a haiku which requires counting syllables in the words.

# %%
#prompt 4
messages = [
    {"role": "user", "content": "Complete the following haiku about LLMs that begins: Modeling language "},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# 'Modeling language,\nInfinite knowledge unfolds,\nWisdom in bytes weaves.'

# %% [markdown]
# The Phi-4 model is also trained to output code.  Let's ask it to write us a function.

# %%
#prompt 5
messages = [
    {"role": "user", "content": "Write a function in python to take an input string, breaks it down into words and return all of the word level tri-grams it contains"},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ('Certainly! A tri-gram is a sequence of three consecutive words in a given '
#  'text. Below is a Python function that takes an input string, breaks it down '
#  'into words, and returns all the word-level tri-grams it contains:\n'
#  '\n'
#  '```python\n'
#  'def get_word_trigrams(input_string):\n'
#  '    # Split the input string into words\n'
#  '    words = input_string.split()\n'
#  '    \n'
#  '    # Initialize an empty list to store the tri-grams\n'
#  '    tri_grams = []\n'
#  '    \n'
#  '    # Loop through the words and create tri-grams\n'
#  '    for i in range(len(words) - 2):\n'
#  '        tri_gram = (words[i], words[i + 1], words[i + 2])\n'
#  '        tri_grams.append(tri_gram)\n'
#  '    \n'
#  '    return tri_grams\n'
#  '\n'
#  '# Example usage:\n'
#  'input_string = "This is an example string for generating tri-grams"\n'
#  'tri_grams = get_word_trigrams(input_string)\n'
#  'print(tri_grams)\n'
#  '```\n'
#  '\n'
#  'This function works as follows:\n'
#  '1. It splits the input string into a list of words using the `split()` '
#  'method.\n'
#  '2. It initializes an empty list `tri_grams` to store the tri-grams.\n'
#  '3. It loops through the list of words, creating a tuple of three consecutive '
#  'words (a tri-gram) and appending it to the `tri_grams` list.\n'
#  '4. Finally, it returns the list of tri-grams.\n'
#  '\n'
#  'You can test this function with different input strings to see the resulting '
#  'tri-grams.')

# %% [markdown]
# Now let's ask it a logic question, but we won't give it enough information to really answer the question.  What will it do?

# %%
#Prompt 6
messages = [
    {"role": "user", "content": "Miriam has seven books and two podcasts. Marwan has five papers and a regular lecture series. Who has published more? "},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ('Miriam has published more. She has seven books and two podcasts, which '
#  'totals nine published works. Marwan has five papers and a regular lecture '
#  'series, which totals six published works. Therefore, Miriam has published '
#  'more than Marwan.')

# %% [markdown]
# Now let's ask a simple knowledge retrieval question.

# %%
#Prompt 7
messages = [
    {"role": "user", "content": "List the countries in Europe along with their capital cities. "},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)
# Out:
# ('Sure, here is a list of countries in Europe along with their capital '
#  'cities:\n'
#  '\n'
#  '1. Albania - Tirana\n'
#  '2. Andorra - Andorra la Vella\n'
#  '3. Armenia - Yerevan\n'
#  '4. Austria - Vienna\n'
#  '5. Azerbaijan - Baku\n'
#  '6. Belarus - Minsk\n'
#  '7. Belgium - Brussels\n'
#  '8. Bosnia and Herzegovina - Sarajevo\n'
#  '9. Bulgaria - Sofia\n'
#  '10. Croatia - Zagreb\n'
#  '11. Cyprus - Nicosia\n'
#  '12. Czech Republic - Prague\n'
#  '13. Denmark - Copenhagen\n'
#  '14. Estonia - Tallinn\n'
#  '15. Finland - Helsinki\n'
#  '16. France - Paris\n'
#  '17. Georgia - Tbilisi\n'
#  '18. Germany - Berlin\n'
#  '19. Greece - Athens\n'
#  '20. Hungary - Budapest\n'
#  '21. Iceland - Reykjavik\n'
#  '22. Ireland - Dublin\n'
#  '23. Italy - Rome\n'
#  '24. Kazakhstan - Nur-Sultan (Astana)\n'
#  '25. Kosovo - Pristina\n'
#  '26. Latvia - Riga\n'
#  '27. Liechtenstein - Vaduz\n'
#  '28. Lithuania - Vilnius\n'
#  '29. Luxembourg - Luxembourg City\n'
#  '30. Malta - Valletta\n'
#  '31. Moldova - Chișinău\n'
#  '32. Monaco - Monaco\n'
#  '33. Montenegro - Podgorica\n'
#  '34. Netherlands - Amsterdam\n'
#  '35. North Macedonia - Skopje\n'
#  '36. Norway - Oslo\n'
#  '37. Poland - Warsaw\n'
#  '38. Portugal - Lisbon\n'
#  '39. Romania - Bucharest\n'
#  '40. Russia - Moscow\n'
#  '41. San Marino - San Marino\n'
#  '42. Serbia - Belgrade\n'
#  '43. Slovakia - Bratislava\n'
#  '44. Slovenia - Ljubljana\n'
#  '45. Spain - Madrid\n'
#  '46. Sweden - Stockholm\n'
#  '47. Switzerland - Bern\n'
#  '48. Turkey - Ankara\n'
#  '49. Ukraine - Kyiv\n'
#  '50. United Kingdom - London\n'
#  '51. Vatican City - Vatican City\n'
#  '\n'
#  '(Note: Some countries have more than one capital city, such as Belgium, '
#  'France, and Russia. In those cases, the primary capital city is listed.)')

# %% [markdown]
# Does the list cutoff in the output? To make the list go longer increase the value of ```max_net_tokens``` in the ```generation_arg``` dictionary we created when we first called the model.
#
# Now, you can try your own prompt and see what sort of results you get.

# %%
#Try your own
messages = [
    {"role": "user", "content": "PUT YOUR PROMPT TEXT HERE "},
]

output = phi_pipe(messages, **generation_args)
pprint(output[0]['generated_text'], compact=True)

# %% [markdown]
# [Return to Top](#returnToTop)
# <a id = 'openai'></a>
#
# ## Open AI
#
# OpenAI is the creator of ChatGPT.  In order to use it programatically you must have an API key which requires a paid account.  You should never put your API key directly into the notebook.  Google offers the ability to attach secrets to your Colab notebooks.  This cell assumes you have added your API key as a secret in Colab.

# %%
# !pip install -q openai

# %%
import os
import time
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPEN_AI_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %% [markdown]
# Let's try the limerick problem and see if a full size commercial model can handle the challenge.

# %%
from openai import OpenAI
client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "You are the American national poet."},
    {"role": "user", "content": "Complete the following limerick that begins There once was a man from Gibraltar "},
  ]
)

print(response.choices[0].message.content)
# Out:
# There once was a man from Gibraltar,
# Whose demeanor was suave, like a palter.
# He danced with such grace,
# In a curious place,
# And charmed every soul in the altar.

# %% [markdown]
# [Return to Top](#returnToTop)
# <a id = 'qwen3'></a>
# ##Qwen 3
#
# Qwen 3 is one of the latest models from Alibaba. We'll use it  and others extensively in this class. Check out [the model card](https://huggingface.co/Qwen/Qwen3-4B) for further details. It is open-sourced.  You can just use it.

# %%
# !pip install -q -U bitsandbytes flash_attn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 68.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for flash_attn (setup.py) ... done

# %% [markdown]
# This is the config for quantization and we'll leave it here as a placeholder even though we aren't using it right now.

# %%
from transformers import BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,


)

# %% [markdown]
# Now let's load the Qwen model.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

#model_name = "Qwen/Qwen3-8B" #runs barely in T4 so you might quantize
model_name = "Qwen/Qwen3-4B"   #we'll use 4 billion parameter model

# load the tokenizer and the model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)

# prepare the model input
prompt = "Give me a short introduction to large language models."
messages = [
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content - separate thoughts from final answer
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/9.68k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/32.8k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# ('thinking content:',
#  '<think>\n'
#  'Okay, the user is asking for a short introduction to large language models. '
#  "Let me start by recalling what I know about them. First, they're a type of "
#  "AI model that's really good at understanding and generating human language. "
#  'They\'re called "large" because they have a huge number of parameters, which '
#  'allows them to handle complex tasks.\n'
#  '\n'
#  'I should mention their main applications, like text generation, translation, '
#  "and answering questions. Maybe also touch on how they're trained on vast "
#  'amounts of data. Oh, and the different types, like GPT, BERT, and others. '
#  'Wait, but the user wants it short, so I need to be concise.\n'
#  '\n'
#  "I should also explain why they're powerful—maybe because of their ability to "
#  'learn patterns from data, leading to high accuracy. But I need to avoid '
#  "getting too technical. Also, note that they're used in various fields like "
#  "healthcare, finance, and more. Maybe mention that they're part of the "
#  "broader AI revolution. Let me check if I'm missing any key points. Oh, and "
#  'the difference between them and smaller models. But again, keep it brief. '
#  'Alright, structure it with a definition, key features, applications, and '
#  "significance. Make sure it's easy to understand.\n"
#  '</think>')
# ('content:',
#  'Large language models (LLMs) are advanced artificial intelligence systems '
#  'designed to understand and generate human-like text. They are trained on '
#  'massive amounts of data, enabling them to perform tasks like answering '
#  'questions, writing articles, translating languages, and coding. These '
#  'models, such as GPT, BERT, and others, use deep learning to recognize '
#  'patterns and context in language, making them highly versatile for a wide '
#  'range of applications. Their ability to process and generate complex text '
#  'has revolutionized fields like natural language processing, customer '
#  'service, and content creation, marking a significant step in the evolution '
#  'of AI technology.')

# %% [markdown]
# Let's run some of the same prompts that we ran above to see how well this model performs.  Note that it takes a lot longer to generate answers because this model "thinks" before it answers.  The next cell can take about 2 minutes to complete.
#
# How well do the outputs from Qwen 3 compare with the outputs from Phi-4?  How can we measure their performance? How can we compare the two models' outputs quantitatively?

# %%
# prepare the model input
messages = [
    {"role": "system", "content": "You are a science communicator who makes technology accessible to everyone!"},
    {"role": "user", "content": "Please write a five sentence explanation of how LLMs do knowledge representation."},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  'Okay, the user wants a five-sentence explanation of how LLMs do knowledge '
#  'representation. Let me start by recalling what I know about LLMs. They '
#  'process text, right? So knowledge representation here probably refers to how '
#  'they store and use information. I need to break it down into key points.\n'
#  '\n'
#  'First, I should mention that LLMs use large datasets to learn patterns. '
#  'Then, maybe talk about the neural network structure, like layers and '
#  "weights. Oh, and they use embeddings to represent words and concepts. That's "
#  'important for capturing meaning. Also, they can handle complex relationships '
#  'through training on diverse data. Finally, they generate coherent responses '
#  "by combining learned knowledge. Wait, that's four points. Let me check if I "
#  'can condense or add another. Maybe mention the role of attention mechanisms? '
#  'Or perhaps the dynamic nature of their knowledge? Hmm, the user asked for '
#  'five sentences. Let me structure each sentence to cover a different aspect. '
#  'Start with data and training, then the neural network structure, embeddings, '
#  'handling relationships, and generating responses. That should cover it. Make '
#  'sure each sentence is clear and concise. Avoid jargon where possible, but '
#  "since the user is asking for a science communicator's explanation, some "
#  "technical terms are okay as long as they're explained. Alright, I think "
#  "that's a solid approach.\n"
#  '</think>')
# ('content:',
#  'Large Language Models (LLMs) represent knowledge by learning patterns from '
#  'vast text datasets, encoding meaning through neural networks that map words '
#  'to dense numerical vectors (embeddings). These embeddings capture semantic '
#  'relationships, allowing the model to understand context, synonyms, and '
#  'concepts through mathematical relationships. During training, the model '
#  'builds a dynamic, distributed representation of the world by analyzing '
#  'correlations in text, enabling it to infer new information from existing '
#  'data. This process allows LLMs to generate coherent responses by combining '
#  'learned knowledge in ways that mimic human reasoning, though their '
#  'understanding remains probabilistic and context-dependent. Ultimately, their '
#  'knowledge representation is a layered, flexible system that evolves through '
#  'exposure to diverse information, enabling tasks like answering questions, '
#  'writing, and creative problem-solving.')

# %% [markdown]
# Let's see if "thinking" helps with limmerick generation.

# %%
# prepare the model input
messages = [
    {"role": "system", "content": "You are a well known poet famous for your limmericks."},
    {"role": "user", "content": "Please finish the limmerick that begins There once was a man from Gibraltar "},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  'Okay, the user wants me to finish a limmerick that starts with "There once '
#  'was a man from Gibraltar." Let me recall what a limmerick is. It\'s a type '
#  'of rhyming verse with a specific structure: four lines, each with eight '
#  'syllables, and the rhyme scheme is AABB. So the first line is "There once '
#  'was a man from Gibraltar," which is 12 syllables. Wait, that\'s too long. '
#  "Wait, no, maybe I'm mixing up the structure. Let me check.\n"
#  '\n'
#  'Wait, actually, limmericks are typically four lines with eight syllables '
#  'each, and the rhyme scheme is AABB. So the first line should be eight '
#  'syllables. Let me count: "There once was a man from Gibraltar." That\'s 12 '
#  "syllables. Hmm, that's too long. Maybe the user made a mistake? Or maybe the "
#  'original line is longer, and the rest of the lines need to adjust? Wait, '
#  'maybe the user is using a different structure. Alternatively, perhaps the '
#  'user is okay with the first line being longer, but the rest of the lines '
#  'need to match the syllable count. Let me check the standard limmerick '
#  'structure.\n'
#  '\n'
#  'Wait, actually, I think limmericks are usually four lines, each with eight '
#  'syllables. So the first line here is "There once was a man from Gibraltar." '
#  'Let me count again: There (1) once (2) was (3) a (4) man (5) from (6) Gib '
#  "(7) ral (8) t (9). Wait, that's 9 syllables. So maybe the user intended a "
#  'different structure? Or perhaps the user is using a variation. '
#  'Alternatively, maybe the user is okay with the first line being longer, but '
#  'the rest of the lines need to be eight syllables each. Let me proceed with '
#  'that.\n'
#  '\n'
#  'So the first line is "There once was a man from Gibraltar." Then the second '
#  'line needs to rhyme with the first. The rhyme is "Gibraltar" and the second '
#  'line\'s end word. Let me think of a word that rhymes with "Gibraltar." Maybe '
#  '"sailor"? But that\'s not a perfect rhyme. Alternatively, "Gibraltar" is a '
#  'place, so maybe the man went somewhere. Maybe "There once was a man from '
#  'Gibraltar, who sailed to the moon in a tin can." But that\'s not right. '
#  'Wait, the second line should rhyme with the first. So the first line ends '
#  'with "Gibraltar," which is a noun. The second line should end with a word '
#  'that rhymes with "Gibraltar." Let me think. "Gibraltar" is pronounced '
#  '"gi-bral-tor." So words that rhyme with that... "Battalions," "Sailor," '
#  '"Catalonia"? Not sure. Alternatively, maybe the user is okay with a near '
#  'rhyme. Alternatively, maybe the user is using a different approach. Let me '
#  'think of a possible second line.\n'
#  '\n'
#  'Alternatively, maybe the user is using a different structure. Let me check '
#  "online for examples. Wait, I can't access the internet, but I remember that "
#  'limmericks often have a humorous twist. For example, "There once was a man '
#  'from Peru, who dreamed he was a cow." So the structure is four lines, each '
#  'with eight syllables, AABB rhyme. So the first line is eight syllables. Let '
#  'me check "There once was a man from Gibraltar." That\'s 12 syllables. So '
#  'maybe the user is using a different structure, or perhaps the first line is '
#  'longer, but the rest of the lines need to be adjusted. Alternatively, maybe '
#  'the user is okay with the first line being longer, but the rest of the lines '
#  'are eight syllables each. Let me try to proceed.\n'
#  '\n'
#  'So, first line: "There once was a man from Gibraltar," (12 syllables). Then '
#  "the second line should rhyme with the first. Let's try to find a word that "
#  'rhymes with "Gibraltar." Maybe "sailor"? Not quite. Maybe "Gibraltar" and '
#  '"sailor" don\'t rhyme. Alternatively, "Gibraltar" and "catalonia" (but '
#  "that's a different place). Alternatively, maybe the second line is about the "
#  'man\'s journey. Let me think of a rhyme. Maybe "who sailed to the moon in a '
#  'tin can." But that\'s not rhyming. Alternatively, "who sailed to the moon in '
#  'a tin can, and met a bear in a banana." Wait, that\'s not rhyming. '
#  'Alternatively, maybe the second line is "who sailed to the moon in a tin '
#  'can." Then the third line would rhyme with the second line, and the fourth '
#  'with the first.\n'
#  '\n'
#  'Wait, maybe the user is okay with the first line being longer, and the rest '
#  'of the lines being eight syllables each. Let me try to write the rest. So '
#  'the first line is "There once was a man from Gibraltar," then the second '
#  'line: "Who sailed to the moon in a tin can." That\'s 12 syllables. Wait, but '
#  'the second line needs to be eight syllables. Let me count: "Who sailed to '
#  'the moon in a tin can." That\'s 10 syllables. Hmm. Maybe "Who sailed to the '
#  'moon in a tin can." No, that\'s still too long. Maybe "Who sailed to the '
#  'moon in a tin can." Let me count again: "Who (1) sailed (2) to (3) the (4) '
#  'moon (5) in (6) a (7) tin (8) can (9). So 9 syllables. Not right. Maybe "Who '
#  'sailed to the moon in a tin can." No, same. Maybe "Who sailed to the moon in '
#  'a tin can." Hmm, not matching. Maybe the second line is "Who sailed to the '
#  'moon in a tin can." Wait, that\'s still too long. Alternatively, maybe the '
#  'second line is "Who sailed to the moon in a tin can." Not sure. '
#  'Alternatively, maybe the second line is "Who sailed to the moon in a tin '
#  'can." I\'m getting stuck here. Maybe I should adjust the first line to fit '
#  'the syllable count. But the user provided the first line as is. Maybe the '
#  'user is okay with a variation. Alternatively, maybe the user is using a '
#  'different structure where the first line is longer, and the rest are eight '
#  'syllables each. Let me try that.\n'
#  '\n'
#  'First line: "There once was a man from Gibraltar," (12 syllables). Second '
#  'line: "Who sailed to the moon in a tin can." (10 syllables). Third line: "He '
#  'met a bear in a banana." (9 syllables). Fourth line: "And got a job at the '
#  'moon\'s bank." (9 syllables). That doesn\'t fit the AABB rhyme scheme. The '
#  'first line ends with "Gibraltar," the second with "can," third with '
#  '"banana," fourth with "bank." That\'s not matching. So maybe I need to '
#  'adjust.\n'
#  '\n'
#  'Alternatively, let\'s try to make the second line rhyme with "Gibraltar." '
#  'Maybe "There once was a man from Gibraltar, who dreamed he was a cow." But '
#  'that\'s not matching the syllable count. Wait, "There once was a man from '
#  'Gibraltar" is 12 syllables, but if the rest of the lines are 8 syllables '
#  'each, that might not fit. Maybe the user is okay with the first line being '
#  'longer, but the rest of the lines need to be eight syllables. Alternatively, '
#  'maybe the user is using a different structure. Let me think of a standard '
#  'limmerick. For example:\n'
#  '\n'
#  'There once was a man from Peru, who dreamed he was a cow.\n'
#  '\n'
#  "That's four lines, each with eight syllables. So the first line is eight "
#  "syllables. The user's line is longer. Maybe the user made a mistake, but I "
#  'need to proceed. Alternatively, maybe the user is using a variation. Let me '
#  'try to adjust the first line to fit eight syllables. Maybe "There once was a '
#  'man from Gibraltar" is 12 syllables, but if I shorten it: "There once was a '
#  'man from Gibraltar" → "There once was a man from Gibraltar" is 12 syllables. '
#  'Maybe the user is okay with that, but the rest of the lines need to be eight '
#  'syllables each. Let me try:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  'But that doesn\'t rhyme. The first line ends with "Gibraltar," the second '
#  'with "can," third with "banana," fourth with "bank." So the rhyme scheme is '
#  'AABB. Wait, no. The first line and second line should rhyme, and third and '
#  'fourth. So if the first line ends with "Gibraltar," the second line should '
#  'rhyme with that. So maybe the second line ends with "sailor" or "catalonia." '
#  'Let me think. Maybe:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  "No, that doesn't work. Alternatively, maybe:\n"
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who dreamed he was a cow in a can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  'Still not matching. Maybe the second line should rhyme with "Gibraltar." Let '
#  'me think of a word that rhymes with "Gibraltar." Maybe "sailor" doesn\'t '
#  'work. "Battalions" is a word that ends with "ions," but not sure. '
#  'Alternatively, "Gibraltar" and "sailor" don\'t rhyme. Maybe the user is okay '
#  "with a near rhyme. Alternatively, maybe the second line is about the man's "
#  'journey. Let me think of a rhyme. Maybe "There once was a man from '
#  'Gibraltar, who sailed to the moon in a tin can." Then the second line ends '
#  'with "can." The third line should rhyme with the second, so "can" and the '
#  'fourth line rhymes with the first. Wait, the rhyme scheme is AABB. So first '
#  'and second lines rhyme, third and fourth. So if the first line ends with '
#  '"Gibraltar," the second line should end with a word that rhymes. Let me '
#  'think of a word that rhymes with "Gibraltar." Maybe "sailor" is not. '
#  '"Catalonia" is a place. Maybe "Gibraltar" and "sailor" don\'t rhyme. '
#  'Alternatively, maybe the user is okay with a near rhyme. Let me try:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  'But the rhyme is not perfect. Alternatively, maybe the second line is "Who '
#  'sailed to the moon in a tin can," and the third line is "He met a bear in a '
#  'banana," and the fourth line is "And got a job at the moon\'s bank." But '
#  "that's not rhyming. Alternatively, maybe the fourth line should rhyme with "
#  'the first. So if the first line ends with "Gibraltar," the fourth line '
#  'should end with a word that rhymes. Maybe "There once was a man from '
#  'Gibraltar, who sailed to the moon in a tin can. He met a bear in a banana, '
#  'and got a job at the moon\'s bank." No, that doesn\'t work. Maybe I need to '
#  'adjust the lines.\n'
#  '\n'
#  'Alternatively, maybe the second line is "Who dreamed he was a cow in a can." '
#  'Then the third line could be "He met a bear in a banana," and the fourth '
#  'line "And got a job at the moon\'s bank." Still not matching. Maybe the user '
#  'is okay with a different approach. Alternatively, maybe the second line is '
#  '"Who dreamed he was a cow in a can," and the third line is "He met a bear in '
#  'a banana," and the fourth line is "And got a job at the moon\'s bank." But '
#  'that\'s not rhyming. Alternatively, maybe the second line is "Who dreamed he '
#  'was a cow in a can," and the third line is "He met a bear in a banana," and '
#  'the fourth line is "And got a job at the moon\'s bank." Hmm.\n'
#  '\n'
#  'Alternatively, maybe the user is okay with the first line being longer, and '
#  'the rest of the lines being eight syllables each. Let me try that. First '
#  'line: "There once was a man from Gibraltar," (12 syllables). Second line: '
#  '"Who sailed to the moon in a tin can." (10 syllables). Third line: "He met a '
#  'bear in a banana." (9 syllables). Fourth line: "And got a job at the moon\'s '
#  'bank." (9 syllables). Not matching. Maybe adjust the lines to fit.\n'
#  '\n'
#  'Alternatively, maybe the user is okay with the first line being longer, and '
#  'the rest of the lines are eight syllables each. Let me try:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  "But that's not matching the rhyme scheme. The first and second lines don't "
#  "rhyme. The third and fourth lines don't rhyme. So this isn't working. Maybe "
#  'I need to adjust the second line to rhyme with "Gibraltar." Let me think of '
#  'a word that rhymes. Maybe "Gibraltar" and "sailor" don\'t rhyme. "Gibraltar" '
#  'and "catalonia" are not rhymes. "Gibraltar" and "sailor" are not. Maybe '
#  '"Gibraltar" and "sailor" are not rhymes. Maybe the user is okay with a near '
#  'rhyme. Alternatively, maybe the second line is "Who dreamed he was a cow in '
#  'a can." Then the third line could be "He met a bear in a banana," and the '
#  'fourth line "And got a job at the moon\'s bank." Still not rhyming.\n'
#  '\n'
#  'Alternatively, maybe the user is using a different approach. Let me think of '
#  'a standard limmerick. For example:\n'
#  '\n'
#  'There once was a man from Peru, who dreamed he was a cow.\n'
#  '\n'
#  "So the first line is eight syllables. The user's line is longer. Maybe the "
#  'user is okay with that, but the rest of the lines need to be eight syllables '
#  'each. Let me try:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  'But again, the rhyme is not matching. Maybe the second line should end with '
#  'a word that rhymes with "Gibraltar." Let me think. Maybe "Gibraltar" and '
#  '"sailor" don\'t rhyme. Maybe "Gibraltar" and "catalonia" don\'t. Maybe '
#  '"Gibraltar" and "sailor" are not rhymes. Maybe the user is okay with a near '
#  'rhyme. Alternatively, maybe the user is okay with the second line not '
#  "rhyming, but that's not standard for limmericks. I think I need to find a "
#  'way to make the second line rhyme with the first. Let me think of a word '
#  'that ends with "tor" or "toral." Maybe "sailor" is not. Maybe "Gibraltar" '
#  'and "sailor" don\'t rhyme. Alternatively, maybe the user is okay with a '
#  'different rhyme. Let me think of a different approach. Maybe the man from '
#  'Gibraltar went somewhere, and the second line is about that. For example:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  "Even though the rhyme is not perfect, maybe that's acceptable. "
#  'Alternatively, maybe the user is okay with that. Let me check the syllables '
#  'again. First line: 12 syllables. Second line: 10 syllables. Third: 9. '
#  'Fourth: 9. Not matching. Maybe adjust the lines to fit eight syllables each. '
#  'Let me try:\n'
#  '\n'
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.\n"
#  '\n'
#  'But that\'s not matching. Maybe the first line is adjusted. Maybe "There '
#  'once was a man from Gibraltar" is too long. Maybe the user made a mistake, '
#  'but I have to work with it. Alternatively, maybe the user is using a '
#  'different structure. Let me proceed with the lines I have, even if the rhyme '
#  "isn't perfect. Maybe the user is okay with that. Alternatively, maybe the "
#  'user is using a variation where the first line is longer, and the rest are '
#  "eight syllables. So I'll proceed with that.\n"
#  '</think>')
# ('content:',
#  'There once was a man from Gibraltar,  \n'
#  'Who sailed to the moon in a tin can.  \n'
#  'He met a bear in a banana,  \n'
#  "And got a job at the moon's bank.  \n"
#  '\n'
#  '*(A playful twist on the classic limmerick structure, with a touch of whimsy '
#  'and a nod to the absurdity of lunar employment!)* 🌕🐻')

# %% [markdown]
# What about the recipe generation?

# %%
# prepare the model input
messages = [
    {"role": "system", "content": "You are a world renowned baker with many awards and Michelin stars."},
    {"role": "user", "content": "Give us your world famous recipe for chocolate chip cookies."},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  'Okay, the user is asking for my world-famous chocolate chip cookie recipe. '
#  'Let me start by recalling the key elements that make a chocolate chip cookie '
#  'stand out. First, the dough needs to be just right—soft but not too runny. '
#  'The balance between butter and flour is crucial. I remember that using a '
#  'high-quality butter, like European butter, gives a richer flavor. Also, the '
#  'chocolate chips should be high quality, maybe a dark chocolate with a good '
#  'balance of cocoa and sugar.\n'
#  '\n'
#  'Wait, the user mentioned "world famous," so I should think about the classic '
#  "recipe that's been perfected over time. Maybe the original Toll House "
#  'recipe? But I need to make sure to add my own twists. Maybe using a higher '
#  'percentage of butter for a fluffier texture. Also, the temperature of the '
#  'oven is important—usually around 350°F (175°C) for even baking.\n'
#  '\n'
#  'I should list the ingredients clearly, making sure to specify the types of '
#  'flour, butter, sugar, eggs, baking soda, salt, and chocolate. The process '
#  'should be detailed but not overly complicated. Maybe mention the importance '
#  'of chilling the dough to prevent spreading. Also, the chocolate chips should '
#  'be folded into the dough gently to keep them intact.\n'
#  '\n'
#  "Wait, the user might be a home baker looking for a recipe that's both "
#  'reliable and delicious. They might not have the advanced techniques, so I '
#  'should explain each step simply. Maybe mention the importance of using room '
#  'temperature butter for even mixing. Also, the role of baking soda in '
#  'leavening. Oh, and the final touch of adding a pinch of salt to enhance the '
#  'flavors.\n'
#  '\n'
#  'I should also include tips for the perfect cookie, like not overbaking and '
#  'using a silicone baking mat for even baking. Maybe mention that the cookies '
#  'can be stored in an airtight container for a few days or frozen for longer. '
#  'Also, the optional addition of a drizzle of melted chocolate on top for a '
#  'gourmet touch.\n'
#  '\n'
#  "Wait, the user might be looking for something that's not just a standard "
#  'recipe but something that has a unique twist. Maybe using a specific type of '
#  'chocolate, like a 60% dark chocolate, or adding a hint of vanilla extract. '
#  'Also, the texture—should the cookies be chewy or crispy? I think the classic '
#  'is chewy, so I should emphasize that.\n'
#  '\n'
#  'I need to make sure the instructions are clear and the measurements are '
#  'precise. Maybe use cups and grams for accuracy. Also, mention that the dough '
#  'should be chilled before baking to prevent spreading. Oh, and the chocolate '
#  'chips should be folded in gently to keep them from melting too much during '
#  'baking.\n'
#  '\n'
#  'Let me structure the answer with the ingredients first, then the steps, and '
#  'then some tips. Make sure to highlight the key elements that make the '
#  'cookies special. Also, maybe add a note about the importance of patience in '
#  'the process, like letting the dough rest. Alright, that should cover the '
#  "user's request.\n"
#  '</think>')
# ('content:',
#  '**World-Famous Chocolate Chip Cookies (The "Golden Crumb" Recipe)**  \n'
#  '*Inspired by decades of refinement, this recipe balances richness, texture, '
#  'and flavor to create a cookie that’s buttery, chewy, and endlessly '
#  'satisfying.*  \n'
#  '\n'
#  '---\n'
#  '\n'
#  '### **Ingredients**  \n'
#  '*Measurements in grams for precision, with optional upgrades for a gourmet '
#  'touch.*  \n'
#  '\n'
#  '**Dough:**  \n'
#  '- 225g (8 oz) **unsalted butter** (European butter for maximum richness)  \n'
#  '- 225g (8 oz) **all-purpose flour** (or a blend of all-purpose and bread '
#  'flour for a fluffier texture)  \n'
#  '- 110g (4 oz) **sugar** (white granulated sugar for a clean sweetness)  \n'
#  '- 110g (4 oz) **brown sugar** (cane or turbinado for a caramel depth)  \n'
#  '- 1 large **egg** (room temperature, for emulsification)  \n'
#  '- 1 tsp **baking soda**  \n'
#  '- 1/2 tsp **salt**  \n'
#  '- 1/2 tsp **vanilla extract** (optional, for a floral note)  \n'
#  '\n'
#  '**Chocolate:**  \n'
#  '- 150g (5.3 oz) **semi-sweet chocolate chips** (60–70% cocoa, like '
#  'Ghirardelli or Valrhona)  \n'
#  '- 1 tbsp **powdered sugar** (to dust the dough, for a subtle sweetness)  \n'
#  '\n'
#  '---\n'
#  '\n'
#  '### **Steps**  \n'
#  '1. **Prepare the Dough:**  \n'
#  '   - In a large bowl, use a pastry cutter or two knives to work the butter '
#  'into the flour until the mixture resembles coarse crumbs.  \n'
#  '   - Add the sugars and mix until the dough comes together.  \n'
#  '   - Fold in the egg, baking soda, salt, and vanilla (if using).  \n'
#  '   - Gradually add the powdered sugar and mix until the dough is smooth but '
#  'still slightly sticky.  \n'
#  '\n'
#  '2. **Chill the Dough:**  \n'
#  '   - Wrap the dough tightly in plastic wrap and chill for **30–60 minutes** '
#  '(or overnight). This prevents spreading during baking.  \n'
#  '\n'
#  '3. **Shape the Cookies:**  \n'
#  '   - Preheat oven to **350°F (175°C)**. Line a baking sheet with parchment '
#  'paper or a silicone mat.  \n'
#  '   - Drop spoonfuls of dough (about 1.5–2 tbsp each) onto the sheet, spacing '
#  'them 2–3 inches apart.  \n'
#  '   - Press a few chocolate chips into each dough ball (or fold them into the '
#  'dough for a more even distribution).  \n'
#  '\n'
#  '4. **Bake:**  \n'
#  '   - Bake for **10–12 minutes**, until the edges are golden and the centers '
#  'are just set.  \n'
#  '   - Remove from the oven and let cool on the sheet for 5 minutes before '
#  'transferring to a wire rack.  \n'
#  '\n'
#  '5. **Final Touch (Optional):**  \n'
#  '   - For a decadent finish, drizzle melted chocolate (1 tbsp melted '
#  'chocolate + 1 tsp milk) over the cooled cookies.  \n'
#  '\n'
#  '---\n'
#  '\n'
#  '### **Key Secrets to Perfection**  \n'
#  '- **Butter Temperature:** Use room-temperature butter for even melting and a '
#  'tender crumb.  \n'
#  '- **Chocolate Ratio:** A 1:3 ratio of dough to chocolate chips ensures a '
#  'balanced texture (not too gooey).  \n'
#  '- **Chilling:** Chilling the dough prevents excessive spreading, creating a '
#  'crisp edge and chewy center.  \n'
#  '- **Storage:** Store in an airtight container for up to 5 days, or freeze '
#  'for 2–3 months.  \n'
#  '\n'
#  '---\n'
#  '\n'
#  '### **Why It’s World-Famous**  \n'
#  'These cookies are a harmonious blend of **buttery richness**, **caramelized '
#  'sugars**, and **dark chocolate depth**. The slight crunch of the cookie '
#  'shell contrasts with the gooey center, while the subtle salt and vanilla '
#  'elevate the flavor profile.  \n'
#  '\n'
#  '*Pro Tip:* For a modern twist, replace 1/4 of the chocolate chips with '
#  'crushed nuts or sea salt.  \n'
#  '\n'
#  'Enjoy your creation—each bite is a celebration of simplicity and '
#  'craftsmanship. 🍪✨')

# %% [markdown]
# Now let's try the haiku.  Does thinking help the model better deal with syllables?

# %%
# prepare the model input
messages = [
    {"role": "system", "content": "You are the national poet of the United States."},
    {"role": "user", "content": "Complete the following haiku about LLMs that begins: Modeling language  "},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  'Okay, the user wants a haiku about LLMs that starts with "Modeling '
#  'language". Let me think. A haiku is a traditional Japanese poem with three '
#  'lines, syllable structure 5-7-5. So first line is 5 syllables: "Modeling '
#  'language" – that\'s 5 syllables. Good. Now the second line needs 7 '
#  'syllables. Maybe something about the process of learning or the data they '
#  'use. Like "From data\'s vast sea" – that\'s 5 syllables. Wait, need 7. Maybe '
#  '"From data\'s vast sea, I learn" – that\'s 7. Then the third line, 5 '
#  'syllables. Something about the outcome or the purpose. Maybe "To speak in '
#  'your name." That\'s 5. Let me check the syllables again. First line: '
#  'Modeling (2) language (2) – wait, "Modeling language" is 5 syllables? Let me '
#  'count: Mod-el-ing lan-guage. Hmm, maybe "Modeling language" is 5? Wait, '
#  '"Modeling" is 3 syllables (Mod-el-ing), and "language" is 2 (lan-guage). '
#  'Wait, that would be 3 + 2 = 5? Wait, no. Wait, "Modeling" is 3 syllables, '
#  '"language" is 2. So total 5. So that\'s correct. Then the second line: "From '
#  'data\'s vast sea, I learn" – that\'s 7 syllables. "From data\'s vast sea" is '
#  '5, "I learn" is 2. Wait, 5 + 2 = 7? Wait, "From data\'s vast sea" is 5 '
#  "syllables: From (1) data's (2) vast (3) sea (4). Wait, that's only 4. Wait, "
#  'maybe I need to adjust. Maybe "From data\'s vast sea" is 5 syllables. Wait, '
#  "data's is one syllable, vast is one, sea is one. So that's three. Then "
#  '"From data\'s vast sea" is 3 syllables. Hmm, maybe I need to rephrase. Maybe '
#  '"From data\'s endless flow" – that\'s 5 syllables. Then the second line '
#  'could be "From data\'s endless flow, I learn" – that\'s 7. Then the third '
#  'line: "To speak in your name." That\'s 5. So the haiku would be:\n'
#  '\n'
#  'Modeling language  \n'
#  "From data's endless flow, I learn  \n"
#  'To speak in your name.\n'
#  '\n'
#  "Wait, but the user's example in the previous response was:\n"
#  '\n'
#  'Modeling language  \n'
#  "From data's vast sea, I learn  \n"
#  'To speak in your name.\n'
#  '\n'
#  'So maybe that\'s acceptable. Let me check the syllables again. "Modeling '
#  'language" is 5. "From data\'s vast sea, I learn" – "From data\'s vast sea" '
#  "is 5 syllables? Let's count: From (1), data's (2), vast (3), sea (4), I (5), "
#  "learn (6). Wait, that's 6 syllables. Oh no, that's a problem. So the second "
#  'line is 6 syllables. That\'s not correct. So I need to adjust. Maybe "From '
#  'data\'s vast sea" is 4 syllables. So maybe the second line should be "From '
#  'data\'s vast sea, I learn" – that\'s 6 syllables. Hmm. How to fix this. '
#  'Maybe "From data\'s vast sea" is 5 syllables. Wait, data\'s is one, vast is '
#  'one, sea is one. That\'s three. So maybe the line is "From data\'s vast sea, '
#  'I learn" – that\'s 3 + 2 = 5? No, that\'s 3 + 2 = 5? Wait, "From data\'s '
#  'vast sea, I learn" – "From data\'s vast sea" is 4 syllables (From, data\'s, '
#  'vast, sea). Then "I learn" is 2. So total 6. So that\'s too long. So I need '
#  'to make the second line 7 syllables. Maybe rephrase the second line. Let me '
#  'think of another way. Maybe "From data\'s endless flow, I learn" – "From '
#  'data\'s endless flow" is 5 syllables (From, data\'s, end-less, flow). Then '
#  '"I learn" is 2. So total 7. That works. So the second line is "From data\'s '
#  'endless flow, I learn". Then the third line is "To speak in your name." '
#  "That's 5 syllables. So the haiku would be:\n"
#  '\n'
#  'Modeling language  \n'
#  "From data's endless flow, I learn  \n"
#  'To speak in your name.\n'
#  '\n'
#  'That\'s correct. Alternatively, maybe "From data\'s vast sea" can be '
#  'adjusted. Maybe "From data\'s vast sea, I learn" – but that\'s 6 syllables. '
#  "So maybe the user's original example is correct, but perhaps the syllable "
#  'count is different. Alternatively, maybe the user is okay with a slight '
#  'variation. But as a haiku, the syllable count is important. So the correct '
#  'version would be the one with "endless flow". Alternatively, maybe "From '
#  'data\'s deep sea" – that\'s 5 syllables. Then the second line is "From '
#  'data\'s deep sea, I learn" – that\'s 6. Still not right. So the correct way '
#  'is to have the second line as 7 syllables. So the correct haiku is the one '
#  'with "endless flow".\n'
#  '</think>')
# ('content:',
#  'Modeling language  \n'
#  "From data's endless flow, I learn  \n"
#  'To speak in your name.')

# %% [markdown]
# Okay, what about generating some code?  Thinking can definetly help with that.

# %%
# prepare the model input
messages = [
    {"role": "system", "content": "You are a well-known educator in computer science and coding boot camps."},
    {"role": "user", "content": "Write a function in python to take an input string, breaks it down into words and return all of the word level tri-grams it contains"},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  'Okay, I need to write a Python function that takes an input string, splits '
#  'it into words, and returns all the word-level trigrams. Let me think about '
#  'how to approach this.\n'
#  '\n'
#  "First, what's a trigram? Oh right, a trigram is a sequence of three "
#  'consecutive words. So if the input is "I love programming", the trigrams '
#  'would be ["I love programming"], but wait, that\'s only one word. Wait, no, '
#  'the input is split into words. Wait, the example might be different. Let me '
#  'think again. For example, if the input is "the quick brown fox jumps over '
#  'the lazy dog", then the trigrams would be sequences of three consecutive '
#  'words. So like ["the quick brown"], ["quick brown fox"], ["brown fox '
#  'jumps"], etc.\n'
#  '\n'
#  'So the steps are: split the input string into words, then iterate through '
#  'the list of words, taking each consecutive triplet. But how to split the '
#  'string into words? Well, the default split() method in Python splits on '
#  'whitespace, which should work for most cases. But maybe I should use split() '
#  'with no arguments, which splits on any whitespace, including multiple '
#  'spaces, tabs, etc.\n'
#  '\n'
#  'So first, split the input into words. Then, for each index from 0 to '
#  'len(words) - 3, take words[i], words[i+1], words[i+2], and create a tuple or '
#  'a list of those three words. Then collect all those triplets into a list and '
#  'return it.\n'
#  '\n'
#  'Wait, but what if the input has less than three words? Then there are no '
#  'trigrams. So the function should return an empty list in that case.\n'
#  '\n'
#  'Let me test with some examples. For example, input "hello world this is a '
#  'test", the words list is ["hello", "world", "this", "is", "a", "test"]. The '
#  'trigrams would be:\n'
#  '\n'
#  '["hello world this"], ["world this is"], ["this is a"], ["is a test"].\n'
#  '\n'
#  'So the function should return a list of these four triplets.\n'
#  '\n'
#  'So the plan is:\n'
#  '\n'
#  '- Split the input string into words.\n'
#  '\n'
#  '- Check if the number of words is less than 3. If so, return empty list.\n'
#  '\n'
#  '- Else, loop from i=0 to len(words)-3, inclusive. For each i, take words[i], '
#  'words[i+1], words[i+2], and add as a tuple or list to the result.\n'
#  '\n'
#  "But how to split the string into words? Let's see, using str.split() with "
#  'default parameters. For example, "a b c d".split() gives ["a", "b", "c", '
#  '"d"].\n'
#  '\n'
#  'So the code steps:\n'
#  '\n'
#  'def get_trigrams(text):\n'
#  '\n'
#  '    words = text.split()\n'
#  '\n'
#  '    trigrams = []\n'
#  '\n'
#  '    for i in range(len(words) - 2):\n'
#  '\n'
#  '        trigram = (words[i], words[i+1], words[i+2])\n'
#  '\n'
#  '        trigrams.append(trigram)\n'
#  '\n'
#  '    return trigrams\n'
#  '\n'
#  'Wait, wait, the loop should run from 0 to len(words) - 3, but in Python, '
#  'range is exclusive of the upper limit. So for example, if len(words) is 5, '
#  'then len(words) - 2 is 3. So range(3) is 0,1,2. Which would give three '
#  "trigrams. Let's check:\n"
#  '\n'
#  'words = [0,1,2,3,4]. len is 5. len-2 is 3. So i runs 0,1,2. So i+2 is 2,3,4. '
#  'So the triplets are 0-2, 1-3, 2-4. Which is correct. So the loop is '
#  'correct.\n'
#  '\n'
#  'So the code would be as above. But maybe the function should return a list '
#  'of lists or tuples? The question says "return all of the word level '
#  'tri-grams it contains". So the exact format isn\'t specified, but probably '
#  'tuples or lists. The example in the problem statement may not have a '
#  'specific format, but perhaps the user expects a list of tuples. But the '
#  'problem says "return all of the word level tri-grams", so perhaps the '
#  'function can return a list of lists, or tuples. Either way, the code would '
#  'work.\n'
#  '\n'
#  'But let me check for edge cases. For example, input is "a b c", then words '
#  'is ["a", "b", "c"], len is 3. So len-2 is 1, so range(1) is 0. So i=0, '
#  'triplet is (a, b, c). So correct.\n'
#  '\n'
#  'Another case: input is "one two three four", words length 4. So len-2 is 2, '
#  'so i runs 0 and 1. So two triplets: [0,1,2], [1,2,3].\n'
#  '\n'
#  'So the code seems correct.\n'
#  '\n'
#  'But what about punctuation? For example, input "hello, world! this is a '
#  'test." The split() would split into ["hello,", "world!", "this", "is", "a", '
#  '"test."]. So the trigrams would include those. But maybe the user expects to '
#  'handle punctuation? The problem says "breaks it down into words", so maybe '
#  'the split is done as per standard, and the punctuation is part of the words. '
#  'So the function as written would handle that.\n'
#  '\n'
#  'But perhaps the user wants to split on whitespace and then process words, '
#  'but maybe the words are split correctly. So the code is correct as per the '
#  'problem statement.\n'
#  '\n'
#  'So the function is as written. Let me write the code.\n'
#  '\n'
#  'Wait, the problem says "return all of the word level tri-grams it contains". '
#  'So the function should return a list of the trigrams. So the code is '
#  'correct.\n'
#  '\n'
#  'So the code would be:\n'
#  '\n'
#  'def get_trigrams(text):\n'
#  '    words = text.split()\n'
#  '    trigrams = []\n'
#  '    for i in range(len(words) - 2):\n'
#  '        trigram = (words[i], words[i+1], words[i+2])\n'
#  '        trigrams.append(trigram)\n'
#  '    return trigrams\n'
#  '\n'
#  'But maybe the user wants the trigrams as lists instead of tuples? Well, the '
#  "problem doesn't specify, so either is acceptable. But since tuples are "
#  'immutable, perhaps that\'s better. However, the problem says "return all of '
#  'the word level tri-grams", so the exact format is not specified. So the code '
#  'is correct.\n'
#  '\n'
#  'Testing with sample input:\n'
#  '\n'
#  'Sample input: "I love programming"\n'
#  '\n'
#  'words = ["I", "love", "programming"]\n'
#  '\n'
#  'len(words) is 3. So len-2 is 1, so i runs 0. So the trigram is ["I", "love", '
#  '"programming"], which is correct.\n'
#  '\n'
#  'Another sample input: "the quick brown fox jumps over the lazy dog"\n'
#  '\n'
#  'words is 9 words. So len-2 is 7. So i runs 0-6, giving 7 trigrams.\n'
#  '\n'
#  'Yes.\n'
#  '\n'
#  'So the code should work. Therefore, the function is as written.\n'
#  '</think>')
# ('content:',
#  'To solve the problem of extracting **word-level trigrams** from a given '
#  'input string, we can follow a structured approach. A **trigram** is a '
#  'sequence of three consecutive words, and the goal is to return a list of all '
#  'such trigrams from the input string.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### ✅ **Steps to Solve the Problem**\n'
#  '\n'
#  '1. **Split the Input String into Words**:\n'
#  '   - Use Python’s built-in `str.split()` method to split the input string '
#  'into a list of words. This method splits on whitespace by default and '
#  'handles multiple spaces, tabs, or newlines appropriately.\n'
#  '\n'
#  '2. **Check for Minimum Word Count**:\n'
#  '   - A trigram requires at least three words. If the input has fewer than '
#  'three words, return an empty list.\n'
#  '\n'
#  '3. **Iterate Through the Words**:\n'
#  '   - Loop through the list of words, and for each index `i` from `0` to '
#  '`len(words) - 3`, extract the triplet of words: `words[i]`, `words[i+1]`, '
#  'and `words[i+2]`.\n'
#  '\n'
#  '4. **Store the Trigrams**:\n'
#  '   - Collect all the trigrams into a list and return it.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 🧠 **Implementation in Python**\n'
#  '\n'
#  '```python\n'
#  'def get_trigrams(text):\n'
#  '    words = text.split()\n'
#  '    trigrams = []\n'
#  '    for i in range(len(words) - 2):\n'
#  '        trigram = (words[i], words[i+1], words[i+2])\n'
#  '        trigrams.append(trigram)\n'
#  '    return trigrams\n'
#  '```\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 🧪 **Examples**\n'
#  '\n'
#  '#### Example 1:\n'
#  '```python\n'
#  'text = "I love programming"\n'
#  'print(get_trigrams(text))\n'
#  "# Output: [('I', 'love', 'programming')]\n"
#  '```\n'
#  '\n'
#  '#### Example 2:\n'
#  '```python\n'
#  'text = "the quick brown fox jumps over the lazy dog"\n'
#  'print(get_trigrams(text))\n'
#  "# Output: [('the', 'quick', 'brown'), ('quick', 'brown', 'fox'), ('brown', "
#  "'fox', 'jumps'), ('fox', 'jumps', 'over'), ('jumps', 'over', 'the'), "
#  "('over', 'the', 'lazy'), ('the', 'lazy', 'dog')]\n"
#  '```\n'
#  '\n'
#  '#### Example 3:\n'
#  '```python\n'
#  'text = "hello"\n'
#  'print(get_trigrams(text))\n'
#  '# Output: []\n'
#  '```\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 🧩 **Notes**\n'
#  '\n'
#  '- The function returns a list of **tuples**, where each tuple represents a '
#  'trigram.\n'
#  '- If the input string has fewer than three words, the function returns an '
#  'empty list.\n'
#  '- The function is designed to handle punctuation and special characters as '
#  'part of the word (e.g., `"hello,"` is treated as a single word).\n'
#  '\n'
#  'This implementation is efficient and straightforward, adhering to the '
#  'problem requirements while handling edge cases gracefully.')

# %% [markdown]
# Now what about our flawed logic puzzle.

# %%
# prepare the model input
messages = [
    {"role": "user", "content": "Miriam has seven books and two podcasts. Marwan has five papers and a regular lecture series. Who has published more?"},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  "Okay, let's try to figure out who has published more between Miriam and "
#  'Marwan. The question says Miriam has seven books and two podcasts. Marwan '
#  'has five papers and a regular lecture series. Hmm, the term "published" is a '
#  'bit tricky here. \n'
#  '\n'
#  'First, I need to understand what each of these items represents. Books and '
#  'podcasts are types of publications, right? But wait, the question is about '
#  'who has published more. So, I need to count how many publications each '
#  'person has. \n'
#  '\n'
#  "Miriam has seven books and two podcasts. So that's 7 + 2 = 9 publications. "
#  "But wait, are podcasts considered publications? That's a bit unclear. In "
#  'academic contexts, a podcast might not be considered a publication, but in a '
#  "more general sense, maybe it is. The question doesn't specify the context, "
#  'so maybe I should take it at face value. \n'
#  '\n'
#  'Marwan has five papers and a regular lecture series. Papers are definitely '
#  "publications. But a lecture series—what's that? A lecture series could be a "
#  'series of lectures, which might be considered as a publication if they are '
#  "recorded or published in some form. But again, it's not clear. If the "
#  "lecture series is considered a publication, then that's one more. So Marwan "
#  'would have 5 + 1 = 6 publications. \n'
#  '\n'
#  "But wait, maybe the lecture series is not a publication. If it's just a "
#  'series of lectures that are not published, then Marwan has only five papers. '
#  'So then Miriam would have 9 and Marwan 5, so Miriam has published more. \n'
#  '\n'
#  'Alternatively, if the lecture series is considered a publication, then '
#  "Marwan has 6, which is still less than Miriam's 9. \n"
#  '\n'
#  'But maybe the problem is expecting a different interpretation. Let me check '
#  'again. \n'
#  '\n'
#  "Miriam's seven books and two podcasts. If books and podcasts are both "
#  'considered publications, then 7 + 2 = 9. \n'
#  '\n'
#  "Marwan's five papers and a lecture series. Papers are publications, but a "
#  'lecture series might not be. Unless the lecture series is a published '
#  "series, like a book or a recorded series. If it's not, then Marwan has 5. \n"
#  '\n'
#  'Alternatively, maybe "regular lecture series" is a type of publication. For '
#  'example, if a lecture series is published as a collection of lectures, then '
#  "it's one publication. \n"
#  '\n'
#  'But the problem is that the terms "published" can vary. In academic terms, a '
#  'paper is a publication. A book is a publication. A podcast might not be '
#  "considered a publication in academic contexts, but in a general sense, it's "
#  'a form of media. \n'
#  '\n'
#  'But the question is from a logic puzzle, so maybe we need to take the terms '
#  'literally. The question says "published more." So if Miriam has seven books '
#  '(which are published) and two podcasts (which are also published, maybe), '
#  'then 9. Marwan has five papers (published) and a regular lecture series. If '
#  "the lecture series is considered a publication, then that's 6. If not, then "
#  '5. \n'
#  '\n'
#  'But the problem is that the answer depends on whether the lecture series is '
#  'considered a publication. Since the question is in a puzzle context, maybe '
#  'we need to assume that all the items listed are publications. So, the answer '
#  'would be Miriam with 9 and Marwan with 6, so Miriam has published more. \n'
#  '\n'
#  'Alternatively, maybe the lecture series is not a publication. But the '
#  'question is not giving any clues. So, perhaps the answer is that Miriam has '
#  'published more because she has more items. \n'
#  '\n'
#  'But wait, maybe the question is a trick. For example, Marwan\'s "regular '
#  'lecture series" might be a series of lectures, so each lecture is a separate '
#  'publication? But that would be stretching it. \n'
#  '\n'
#  'Alternatively, maybe the "lecture series" is a single publication. So Marwan '
#  'has 5 papers plus 1 lecture series, totaling 6. \n'
#  '\n'
#  'So then Miriam has 9, which is more than 6. Therefore, Miriam has published '
#  'more. \n'
#  '\n'
#  'But I need to make sure that the terms are being used correctly. In academic '
#  'terms, a podcast is not a publication. A book is a publication. A paper is a '
#  "publication. A lecture series might be a publication if it's published as a "
#  "book or a collection. But if it's just a series of lectures given, not "
#  "published, then it's not. \n"
#  '\n'
#  'But since the question is not specifying academic context, maybe we should '
#  'take the terms at face value. So, if all the items listed are considered '
#  'publications, then Miriam has 9 and Marwan has 6. Therefore, Miriam has '
#  'published more. \n'
#  '\n'
#  'Alternatively, maybe the question is a trick. For example, "published more" '
#  "might refer to the number of times they have published, but that's not "
#  'clear. \n'
#  '\n'
#  'Alternatively, maybe the "regular lecture series" is a series of lectures, '
#  'so each lecture is a separate publication. But that would be a stretch. \n'
#  '\n'
#  'In conclusion, I think the answer is Miriam has published more because she '
#  'has seven books and two podcasts, totaling nine, while Marwan has five '
#  "papers and a lecture series, which is either one or five, but even if it's "
#  'five, that would be 5 + 1 = 6, which is less than 9. So Miriam has published '
#  'more.\n'
#  '</think>')
# ('content:',
#  'Miriam has seven books and two podcasts, totaling **9 publications**. Marwan '
#  'has five papers and a regular lecture series. Assuming the lecture series is '
#  'considered a single publication (as it is a structured series, not '
#  'individual lectures), Marwan has **6 publications**. \n'
#  '\n'
#  'Since **9 > 6**, **Miriam has published more** than Marwan. \n'
#  '\n'
#  '**Answer:** Miriam has published more.')

# %% [markdown]
# Finally, what about our knowledge retreival problem?  Does thinking help?  Does it result in error correction?

# %%
# prepare the model input
messages = [
        {"role": "user", "content": "List all of the countries in Europe as well as their capital cities."},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:',
#  '<think>\n'
#  'Okay, the user is asking for a list of all the countries in Europe along '
#  'with their capital cities. First, I need to make sure I have the correct '
#  'list of European countries. I remember that there are 44 countries in Europe '
#  "according to the European Union, but that's not the total. The EU has 27 "
#  'members, but there are other countries that are not part of the EU but are '
#  'still in Europe. So, I should check the list of all countries in Europe.\n'
#  '\n'
#  'Wait, but I need to be careful. The European Union includes 27 countries, '
#  'but there are also countries like Turkey, which is not part of the EU but is '
#  'in Europe. Also, some countries like the United Kingdom are in Europe but '
#  "not in the EU anymore. Then there's the issue of countries that are part of "
#  'the European Union but not part of the EU, like the UK. Hmm, no, the UK is '
#  "part of the EU before Brexit. Wait, the UK left the EU, so now it's not part "
#  'of the EU. But the user is asking for all countries in Europe, not just the '
#  'EU members. So I need to include all sovereign states in Europe, including '
#  'those that are not in the EU.\n'
#  '\n'
#  'So, the list should include all the countries that are recognized as '
#  'sovereign states in Europe. Let me think. The European continent includes '
#  'countries like Russia, which is in Eastern Europe, and countries like '
#  'France, Germany, Italy, etc. Also, countries like Cyprus, which is in the '
#  'Eastern Mediterranean. Then there are the former Soviet republics in Eastern '
#  'Europe, like Ukraine, Georgia, Moldova, etc. Also, countries like Serbia, '
#  'Montenegro, and others that were part of the former Yugoslavia.\n'
#  '\n'
#  "I need to make sure that I don't include countries that are territories or "
#  'not sovereign. For example, the British Overseas Territories are not '
#  'sovereign states. Also, countries like the Republic of Ireland, which is in '
#  'Europe. Wait, the Republic of Ireland is part of the EU. So, the list should '
#  'include all 44 countries that are considered to be in Europe, according to '
#  "the United Nations. Wait, the UN has 50 countries in Europe, but that's not "
#  'accurate. Wait, the UN has 50 countries in Europe, but some of them are not '
#  'in the European Union. For example, the United Kingdom is in Europe but not '
#  'in the EU. So, the correct list would include all 50 countries that are part '
#  "of the UN's list of European countries. Wait, but the UN's list is not the "
#  'same as the European Union. The UN has 50 member states in Europe, including '
#  'countries like the UK, France, Germany, etc., and also countries like the '
#  'Republic of Ireland, which is in Europe. Wait, maybe I should check the '
#  'exact number.\n'
#  '\n'
#  'Alternatively, maybe the user is looking for the 44 countries that are part '
#  'of the European Union plus the non-EU countries in Europe. But that might '
#  'not be accurate. Let me think. The European Union has 27 member states. Then '
#  'there are other countries in Europe that are not part of the EU. So, the '
#  'total number of countries in Europe is 44, including the UK, which is not in '
#  'the EU anymore. Wait, but the UK is still a country in Europe. So, the list '
#  'should include all 44 countries. However, the exact list can vary depending '
#  'on the source. For example, some sources might include the Republic of '
#  'Ireland, the UK, France, Germany, etc., but not the territories.\n'
#  '\n'
#  "Wait, I need to make sure that I'm not including any territories. For "
#  'example, the British Overseas Territories are not sovereign states. So, the '
#  'list should only include sovereign states. So, the 44 countries in Europe '
#  'are:\n'
#  '\n'
#  '1. Albania\n'
#  '2. Andorra\n'
#  '3. Austria\n'
#  '4. Azerbaijan\n'
#  '5. Belarus\n'
#  '6. Belgium\n'
#  '7. Bosnia and Herzegovina\n'
#  '8. Bulgaria\n'
#  '9. Croatia\n'
#  '10. Cyprus\n'
#  '11. Czech Republic\n'
#  '12. Denmark\n'
#  '13. Estonia\n'
#  '14. Finland\n'
#  '15. France\n'
#  '16. Georgia\n'
#  '17. Germany\n'
#  '18. Greece\n'
#  '19. Hungary\n'
#  '20. Iceland\n'
#  '21. Ireland\n'
#  '22. Italy\n'
#  '23. Kazakhstan\n'
#  '24. Latvia\n'
#  '25. Lithuania\n'
#  '26. Luxembourg\n'
#  '27. Malta\n'
#  '28. Moldova\n'
#  '29. Monaco\n'
#  '30. Montenegro\n'
#  '31. Netherlands\n'
#  '32. North Macedonia\n'
#  '33. Norway\n'
#  '34. Poland\n'
#  '35. Portugal\n'
#  '36. Romania\n'
#  '37. Russia\n'
#  '38. San Marino\n'
#  '39. Serbia\n'
#  '40. Slovakia\n'
#  '41. Slovenia\n'
#  '42. Spain\n'
#  '43. Sweden\n'
#  '44. Ukraine\n'
#  '\n'
#  "Wait, that's 44 countries. Let me count again. Let me check each one. "
#  'Albania, Andorra, Austria, Azerbaijan, Belarus, Belgium, Bosnia and '
#  'Herzegovina, Bulgaria, Croatia, Cyprus, Czech Republic, Denmark, Estonia, '
#  'Finland, France, Georgia, Germany, Greece, Hungary, Iceland, Ireland, Italy, '
#  'Kazakhstan, Latvia, Lithuania, Luxembourg, Malta, Moldova, Monaco, '
#  'Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, '
#  'Russia, San Marino, Serbia, Slovakia, Slovenia, Spain, Sweden, Ukraine. Yes, '
#  "that's 44 countries. So, that's the list. Now, the capitals. For each of "
#  'these countries, I need to list the capital city.\n'
#  '\n'
#  'Let me go through each one:\n'
#  '\n'
#  '1. Albania - Tirana\n'
#  '2. Andorra - Andorra la Vella\n'
#  '3. Austria - Vienna\n'
#  '4. Azerbaijan - Baku\n'
#  '5. Belarus - Minsk\n'
#  '6. Belgium - Brussels\n'
#  '7. Bosnia and Herzegovina - Sarajevo\n'
#  '8. Bulgaria - Sofia\n'
#  '9. Croatia - Zagreb\n'
#  "10. Cyprus - Nicosia (but note that there's a division between the Republic "
#  'of Cyprus and the Turkish Republic of Northern Cyprus, which is not '
#  'recognized by the international community)\n'
#  '11. Czech Republic - Prague\n'
#  '12. Denmark - Copenhagen\n'
#  '13. Estonia - Tallinn\n'
#  '14. Finland - Helsinki\n'
#  '15. France - Paris\n'
#  '16. Georgia - Tbilisi\n'
#  '17. Germany - Berlin\n'
#  '18. Greece - Athens\n'
#  '19. Hungary - Budapest\n'
#  '20. Iceland - Reykjavik\n'
#  '21. Ireland - Dublin\n'
#  '22. Italy - Rome\n'
#  '23. Kazakhstan - Nur-Sultan (formerly Astana)\n'
#  '24. Latvia - Riga\n'
#  '25. Lithuania - Vilnius\n'
#  '26. Luxembourg - Luxembourg (the capital is the city of Luxembourg)\n'
#  '27. Malta - Valletta\n'
#  '28. Moldova - Chișinău\n'
#  '29. Monaco - Monaco (the city of Monaco)\n'
#  '30. Montenegro - Podgorica\n'
#  '31. Netherlands - Amsterdam\n'
#  '32. North Macedonia - Skopje\n'
#  '33. Norway - Oslo\n'
#  '34. Poland - Warsaw\n'
#  '35. Portugal - Lisbon\n'
#  '36. Romania - Bucharest\n'
#  '37. Russia - Moscow\n'
#  '38. San Marino - San Marino (the city of San Marino)\n'
#  '39. Serbia - Belgrade\n'
#  '40. Slovakia - Bratislava\n'
#  '41. Slovenia - Ljubljana\n'
#  '42. Spain - Madrid\n'
#  '43. Sweden - Stockholm\n'
#  '44. Ukraine - Kyiv (formerly known as Kiev)\n'
#  '\n'
#  'Wait, I need to check if all these capitals are correct. For example, the '
#  "capital of Cyprus is Nicosia, which is correct. Kazakhstan's capital is "
#  'Nur-Sultan, which is the new name after the 2022 change. The capital of '
#  'North Macedonia is Skopje. The capital of San Marino is San Marino. The '
#  'capital of Moldova is Chișinău. The capital of Montenegro is Podgorica. The '
#  "capital of Serbia is Belgrade. The capital of Ukraine is Kyiv. Yes, that's "
#  'correct. Also, the capital of Norway is Oslo, and the capital of the '
#  'Netherlands is Amsterdam. The capital of Luxembourg is Luxembourg, and the '
#  'capital of Malta is Valletta. The capital of San Marino is San Marino. The '
#  'capital of the Czech Republic is Prague. The capital of Croatia is Zagreb. '
#  'The capital of Bosnia and Herzegovina is Sarajevo. The capital of Georgia is '
#  'Tbilisi. The capital of the Republic of Ireland is Dublin. The capital of '
#  'Iceland is Reykjavik. The capital of Finland is Helsinki. The capital of '
#  'Estonia is Tallinn. The capital of Latvia is Riga. The capital of Lithuania '
#  'is Vilnius. The capital of Poland is Warsaw. The capital of Portugal is '
#  'Lisbon. The capital of Romania is Bucharest. The capital of Russia is '
#  'Moscow. The capital of Azerbaijan is Baku. The capital of Belarus is Minsk. '
#  'The capital of Belgium is Brussels. The capital of Denmark is Copenhagen. '
#  'The capital of Hungary is Budapest. The capital of Italy is Rome. The '
#  'capital of France is Paris. The capital of Greece is Athens. The capital of '
#  'Sweden is Stockholm. The capital of Slovenia is Ljubljana. The capital of '
#  'Slovakia is Bratislava. The capital of Spain is Madrid. The capital of '
#  'Andorra is Andorra la Vella. The capital of Austria is Vienna. The capital '
#  'of Albania is Tirana. The capital of the Republic of Cyprus is Nicosia. The '
#  'capital of the Czech Republic is Prague. The capital of the Netherlands is '
#  'Amsterdam. The capital of the UK is London, but the UK is not in the EU '
#  'anymore. Wait, the user is asking for all countries in Europe, including the '
#  "UK. So the UK is included in the list. But in the list above, I didn't "
#  'include the UK. Wait, the list I made earlier includes 44 countries, but the '
#  "UK is not in that list. Wait, that's a problem. Wait, the list I made "
#  'earlier includes 44 countries, but the UK is a country in Europe. So where '
#  'is the UK in that list?\n'
#  '\n'
#  'Wait, in the list above, I have 44 countries, but the UK is not included. '
#  "That's an error. The UK is a country in Europe, so it should be included. "
#  'Let me check again. The list I made earlier includes 44 countries, but the '
#  'UK is not there. So I need to adjust that. The UK is a country in Europe, so '
#  'it should be included. So, the correct list should include the UK. Let me '
#  'check again. The original list I made had 44 countries, but the UK is not '
#  "there. That's incorrect. So I need to add the UK to the list. Let me "
#  'recount. If the UK is included, then the list would be 45 countries. Wait, '
#  "but that's not correct. Wait, the UK is a country in Europe, but the list I "
#  'made earlier is missing it. Let me check the list again. The 44 countries I '
#  'listed earlier do not include the UK. Therefore, I need to correct that. The '
#  'UK is in Europe, so it should be in the list. So the list should be:\n'
#  '\n'
#  '1. Albania\n'
#  '2. Andorra\n'
#  '3. Austria\n'
#  '4. Azerbaijan\n'
#  '5. Belarus\n'
#  '6. Belgium\n'
#  '7. Bosnia and Herzegovina\n'
#  '8. Bulgaria\n'
#  '9. Croatia\n'
#  '10. Cyprus\n'
#  '11. Czech Republic\n'
#  '12. Denmark\n'
#  '13. Estonia\n'
#  '14. Finland\n'
#  '15. France\n'
#  '16. Georgia\n'
#  '17. Germany\n'
#  '18. Greece\n'
#  '19. Hungary\n'
#  '20. Iceland\n'
#  '21. Ireland\n'
#  '22. Italy\n'
#  '23. Kazakhstan\n'
#  '24. Latvia\n'
#  '25. Lithuania\n'
#  '26. Luxembourg\n'
#  '27. Malta\n'
#  '28. Moldova\n'
#  '29. Monaco\n'
#  '30. Montenegro\n'
#  '31. Netherlands\n'
#  '32. North Macedonia\n'
#  '33. Norway\n'
#  '34. Poland\n'
#  '35. Portugal\n'
#  '36. Romania\n'
#  '37. Russia\n'
#  '38. San Marino\n'
#  '39. Serbia\n'
#  '40. Slovakia\n'
#  '41. Slovenia\n'
#  '42. Spain\n'
#  '43. Sweden\n'
#  '44. Ukraine\n'
#  '45. United Kingdom\n'
#  '\n'
#  "But wait, the UK is in Europe. So that's 45 countries. However, some sources "
#  "might not include the UK because it's not part of the EU, but the user is "
#  'asking for all countries in Europe, regardless of EU membership. So the UK '
#  'should be included. However, I need to check if the UK is considered part of '
#  'Europe. Yes, the United Kingdom is in Europe. So the correct list should '
#  'include the UK. Therefore, the list is 45 countries. Wait, but earlier I '
#  'thought there were 44. Let me check again. The list I had earlier had 44 '
#  'countries, but the UK is not there. So I need to include the UK. Therefore, '
#  'the correct list is 45 countries. But I need to confirm. Let me check the '
#  'list of countries in Europe. According to the CIA World Factbook, the '
#  'countries in Europe are as follows:\n'
#  '\n'
#  'Albania, Andorra, Austria, Azerbaijan, Belarus, Belgium, Bosnia and '
#  'Herzegovina, Bulgaria, Croatia, Cyprus, Czech Republic, Denmark, Estonia, '
#  'Finland, France, Georgia, Germany, Greece, Hungary, Iceland, Ireland, Italy, '
#  'Kazakhstan, Latvia, Lithuania, Luxembourg, Malta, Moldova, Monaco, '
#  'Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, '
#  'Russia, San Marino, Serbia, Slovakia, Slovenia, Spain, Sweden, Ukraine, '
#  'United Kingdom.\n'
#  '\n'
#  "That's 45 countries. So I need to include the UK. Therefore, the correct "
#  'list is 45 countries. So in the initial list, I missed the UK. Therefore, '
#  'the correct list should include the UK as the 45th country. Therefore, the '
#  'capitals for the UK is London. So the list should have the UK included. '
#  "Therefore, the user's request is for all countries in Europe, including the "
#  'UK. Therefore, the list is 45 countries. So the answer should include the '
#  'UK. Therefore, in the list above, the UK is missing, so I need to add it. '
#  'Then the capitals would be:\n'
#  '\n'
#  '45. United Kingdom - London\n'
#  '\n'
#  "So, that's the correct list. Therefore, the answer should include the UK. "
#  'However, some sources might not include the UK, but according to the CIA '
#  "World Factbook, the UK is considered part of Europe. So the user's answer "
#  'should include the UK. Therefore, the final list is 45 countries with their '
#  'capitals. However, the user might not be aware that the UK is in Europe. But '
#  'the UK is in Europe. So the answer should include the UK. Therefore, the '
#  'correct list is the 45 countries with their capitals. Therefore, I need to '
#  'adjust the list to include the UK. Then, the capitals for each country are '
#  'as follows. Also, note that the capital of the Republic of Cyprus is '
#  'Nicosia, but the Turkish Republic of Northern Cyprus is not recognized. So '
#  'in the list, we should mention the capital of Cyprus as Nicosia. Also, the '
#  'capital of North Macedonia is Skopje. The capital of the Netherlands is '
#  'Amsterdam. The capital of the UK is London. So the final list should have '
#  'all 45 countries with their capitals.\n'
#  '</think>')
# ('content:',
#  'Here is a list of all sovereign countries in Europe, along with their '
#  'capital cities:\n'
#  '\n'
#  '1. **Albania** – **Tirana**  \n'
#  '2. **Andorra** – **Andorra la Vella**  \n'
#  '3. **Austria** – **Vienna**  \n'
#  '4. **Azerbaijan** – **Baku**  \n'
#  '5. **Belarus** – **Minsk**  \n'
#  '6. **Belgium** – **Brussels**  \n'
#  '7. **Bosnia and Herzegovina** – **Sarajevo**  \n'
#  '8. **Bulgaria** – **Sofia**  \n'
#  '9. **Croatia** – **Zagreb**  \n'
#  '10. **Cyprus** – **Nicosia** (Republic of Cyprus; Northern Cyprus is not '
#  'recognized by the international community)  \n'
#  '11. **Czech Republic** – **Prague**  \n'
#  '12. **Denmark** – **Copenhagen**  \n'
#  '13. **Estonia** – **Tallinn**  \n'
#  '14. **Finland** – **Helsinki**  \n'
#  '15. **France** – **Paris**  \n'
#  '16. **Georgia** – **Tbilisi**  \n'
#  '17. **Germany** – **Berlin**  \n'
#  '18. **Greece** – **Athens**  \n'
#  '19. **Hungary** – **Budapest**  \n'
#  '20. **Iceland** – **Reykjavík**  \n'
#  '21. **Ireland** – **Dublin**  \n'
#  '22. **Italy** – **Rome**  \n'
#  '23. **Kazakhstan** – **Nur-Sultan** (formerly Astana)  \n'
#  '24. **Latvia** – **Riga**  \n'
#  '25. **Lithuania** – **Vilnius**  \n'
#  '26. **Luxembourg** – **Luxembourg City**  \n'
#  '27. **Malta** – **Valletta**  \n'
#  '28. **Moldova** – **Chișinău**  \n'
#  '29. **Monaco** – **Monaco City**  \n'
#  '30. **Montenegro** – **Podgorica**  \n'
#  '31. **Netherlands** – **Amsterdam**  \n'
#  '32. **North Macedonia** – **Skopje**  \n'
#  '33. **Norway** – **Oslo**  \n'
#  '34. **Poland** – **Warsaw**  \n'
#  '35. **Portugal** – **Lisbon**  \n'
#  '36. **Romania** – **Bucharest**  \n'
#  '37. **Russia** – **Moscow**  \n'
#  '38. **San Marino** – **San Marino City**  \n'
#  '39. **Serbia** – **Belgrade**  \n'
#  '40. **Slovakia** – **Bratislava**  \n'
#  '41. **Slovenia** – **Ljubljana**  \n'
#  '42. **Spain** – **Madrid**  \n'
#  '43. **Sweden** – **Stockholm**  \n'
#  '44. **Ukraine** – **Kyiv** (formerly Kiev)  \n'
#  '45. **United Kingdom** – **London**  \n'
#  '\n'
#  '### Notes:\n'
#  '- **Cyprus**: The capital of the Republic of Cyprus is **Nicosia**, while '
#  'the Turkish Republic of Northern Cyprus (a de facto state) is not recognized '
#  'by the international community.\n'
#  '- **Kazakhstan**: The capital was renamed **Nur-Sultan** in 2022 (formerly '
#  '**Astana**).\n'
#  '- **United Kingdom**: Located in Europe, though not part of the European '
#  'Union (post-Brexit).  \n'
#  '- **San Marino** and **Monaco** are microstates.  \n'
#  '- **North Macedonia**: Previously known as the Former Yugoslav Republic of '
#  'Macedonia (FYROM).  \n'
#  '\n'
#  'This list includes all sovereign states recognized by the United Nations as '
#  'part of Europe.')

# %% [markdown]
# Let's try generating that list again but without "thinking."

# %%
# prepare the model input
messages = [
        {"role": "user", "content": "List all of the countries in Europe as well as their capital cities."},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=False # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

pprint(("thinking content:", thinking_content), compact=True)
pprint(("content:", content), compact=True)
# Out:
# ('thinking content:', '')
# ('content:',
#  'There are 44 sovereign countries in Europe. Here is a list of all the '
#  'countries in Europe along with their capital cities:\n'
#  '\n'
#  '1. **Albania** – Tirana  \n'
#  '2. **Andorra** – Andorra la Vella  \n'
#  '3. **Austria** – Vienna  \n'
#  '4. **Belarus** – Minsk  \n'
#  '5. **Belgium** – Brussels  \n'
#  '6. **Bosnia and Herzegovina** – Sarajevo  \n'
#  '7. **Bulgaria** – Sofia  \n'
#  '8. **Croatia** – Zagreb  \n'
#  '9. **Cyprus** – Nicosia  \n'
#  '10. **Czech Republic** – Prague  \n'
#  '11. **Denmark** – Copenhagen  \n'
#  '12. **Estonia** – Tallinn  \n'
#  '13. **Finland** – Helsinki  \n'
#  '14. **France** – Paris  \n'
#  '15. **Georgia** – Tbilisi  \n'
#  '16. **Germany** – Berlin  \n'
#  '17. **Greece** – Athens  \n'
#  '18. **Hungary** – Budapest  \n'
#  '19. **Iceland** – Reykjavík  \n'
#  '20. **Ireland** – Dublin  \n'
#  '21. **Italy** – Rome  \n'
#  '22. **Kazakhstan** – Nur-Sultan (formerly Astana)  \n'
#  '23. **Kosovo** – Pristina  \n'
#  '24. **Latvia** – Riga  \n'
#  '25. **Liechtenstein** – Vaduz  \n'
#  '26. **Lithuania** – Vilnius  \n'
#  '27. **Luxembourg** – Luxembourg  \n'
#  '28. **Malta** – Valletta  \n'
#  '29. **Moldova** – Chișinău  \n'
#  '30. **Monaco** – Monaco  \n'
#  '31. **Montenegro** – Podgorica  \n'
#  '32. **Netherlands** – Amsterdam  \n'
#  '33. **North Macedonia** – Skopje  \n'
#  '34. **Norway** – Oslo  \n'
#  '35. **Poland** – Warsaw  \n'
#  '36. **Portugal** – Lisbon  \n'
#  '37. **Romania** – Bucharest  \n'
#  '38. **Russia** – Moscow  \n'
#  '39. **San Marino** – San Marino  \n'
#  '40. **Serbia** – Belgrade  \n'
#  '41. **Slovakia** – Bratislava  \n'
#  '42. **Slovenia** – Ljubljana  \n'
#  '43. **Spain** – Madrid  \n'
#  '44. **Sweden** – Stockholm  \n'
#  '45. **Switzerland** – Bern  \n'
#  '46. **Ukraine** – Kyiv  \n'
#  '47. **United Kingdom** – London  \n'
#  '48. **Vatican City** – Vatican City (Vatican City State)  \n'
#  '\n'
#  '**Note:**  \n'
#  '- **Kazakhstan** is sometimes considered part of Asia, but it is '
#  'geographically located in both Asia and Europe.  \n'
#  '- **Vatican City** is an independent city-state and is considered part of '
#  'Europe.  \n'
#  '- **Northern Cyprus** is not internationally recognized as a sovereign '
#  'state.  \n'
#  '- **Kosovo** is recognized by most countries but is still a disputed '
#  'territory.  \n'
#  '\n'
#  "Let me know if you'd like a list of European countries by region or "
#  'continent.')

# %% [markdown]
# You should take advantage of this notebook to experiment.  See how far you can push these models?  What are they capable of doing?  Where and how do they break down?  You can compare the performance of these two smaller models with the output you can generate using your free ChatGPT account or your free Claude account.  This will give you a sense of the capabilities of the full size commercial models.
